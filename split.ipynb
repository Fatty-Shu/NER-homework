# %%
def write_chinese_char_by_line(chinese_text, file_path):
    """
    将指定中文文本按单个文字拆分，每个文字一行写入文件
    :param chinese_text: 待拆分的中文文本（可包含其他字符，同样会逐字符拆分）
    :param file_path: 输出文件路径（如"./chinese_chars.txt"）
    """
    # 打开文件，使用utf-8编码（必须指定，避免中文乱码），模式为写入（w会覆盖原有文件，a为追加）
    with open(file_path, 'w', encoding='utf-8') as f:
        # 遍历中文文本的每个字符（Python中字符串可直接迭代，每个迭代单位即为单个字符）
        for char in chinese_text:
            # 写入单个字符，并换行（\n实现每行一个文字）
            f.write(char  + '	O\n')

# --------------- 使用示例 ---------------
if __name__ == '__main__':
    # 1. 指定需要拆分的中文文本
    target_chinese = """本网讯　12月12日，农业农村部与河南省委省政府举行工作会谈。农业农村部党组书记、部长韩俊，河南省委书记刘宁，省委副书记、省长王凯出席。双方进行了工作交流。

　　韩俊指出，河南是粮食大省、农业大省，省委省政府坚持把“三农”工作摆在重中之重位置，始终把粮食生产作为头等大事来抓，扎实有力推进乡村全面振兴，农业强省建设迈出坚实步伐。农业农村部将深入学习贯彻习近平总书记关于河南工作的重要指示精神，认真落实中央经济工作会议部署，支持河南稳步提升粮食产能，抓好粮油作物大面积单产提升，高质量推进高标准农田建设，提升农业防灾减灾救灾能力。支持河南强化农业科技装备支撑，推进农产品加工业转型升级，着力提高农业质量效益和竞争力，因地制宜发展乡村富民产业，促进农民稳定增收。支持河南持续巩固拓展脱贫攻坚成果，建立健全常态化防止返贫致贫机制，强化产业就业等开发式帮扶，牢牢守住不发生规模性返贫致贫底线。支持河南学习运用“千万工程”经验，补齐农村现代生活条件短板，扎实推进宜居宜业和美乡村建设。

　　刘宁、王凯代表省委、省政府向农业农村部长期以来给予河南农业农村发展的支持表示感谢。刘宁表示，当前，全省上下正深入贯彻党的二十届四中全会精神，全面落实习近平总书记关于“三农”工作的重要论述和在河南考察时重要讲话精神，按照省委十一届十次全会部署，聚焦“1+2+4+N”目标任务体系，坚持农业农村优先发展，坚决扛牢粮食安全责任，千方百计抓好粮食生产，有力有效推进乡村全面振兴，加快把农业建成现代化大产业，推动农业增效益、农民增收入、农村增活力，呈现出稳中求进、提质增效的发展态势。刚刚闭幕的中央经济工作会议就坚持不懈抓好“三农”工作作出一系列重要部署，为我们指明了前进方向。希望农业农村部一如既往支持河南发展，进一步深化省部合作，指导科学编制“十五五”农业农村现代化规划、持续巩固拓展脱贫攻坚成果、推进农业科技创新等，持续提升农业综合生产能力和质量效益。

　　农业农村部党组成员、副部长麦尔丹·木盖提，总农艺师潘文博，河南省副省长李酌出席会谈。"""
    # 2. 指定输出文件路径
    output_file = "agri_news_data"
    # 3. 调用函数执行操作
    write_chinese_char_by_line(target_chinese, output_file)
    print(f"操作完成！已将文本拆分后写入文件：{output_file}")
# Out:
# 操作完成！已将文本拆分后写入文件：agri_news_data
